# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
#  !! EXPLOARATRY DATA ANALYSIS !! TMDB

# %% [raw]
# Project Objective::
# The objective of the project is to use Python programming to analyze a movie data to perform exploratory data analysis by answering the questions in the upcoming slides.

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# TMDB Movie Data Analysis::
#
# Movies that cost over $100 million can still fail, why so? Movie lovers might have different interests.
#
# A production company wants to analyze a movie dataset to identify what kinds of movies perform well in cinemas, which genres they belong to, and so on. It will help the company predict if a movie will be a commercial success, if the movie will be highly rated, etc.

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %%
#IMPORTING LIBRARAY::
import numpy as NP
import pandas as PD
import matplotlib.pyplot as PLT
import seaborn as SNS 
import json
import ast

# %%
def parse_col_json(column,key):

    for index,i in zip(DATA.index,DATA[column].apply(json.loads)):
        list1=[]
        for j in range(len(i)):            # iterating over column length
            list1.append((i[j][key]))# the key 'name' contains the name of the genre
        DATA.loc[index,column]=str(list1)

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# TASK1:
# Load the movie dataset in the Python notebook. Display the numbers of rows and columns in -the dataset. Display the titles and genres of the first 50 movies from the dataset.

# %%
#LOADING THE DATA::
DATA=PD.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
DATA
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#SHAPE OF THE DATA::
DATA.shape
# Out:
# (4803, 20)

# %%
DATA.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
parse_col_json("genres","name")

# %%
#FIRST 50 ROWS OF GENRE AND TITLE::
DATA[["genres","title"]].head(50)
# Out:
#                                                genres  \
# 0   ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1                  ['Adventure', 'Fantasy', 'Action']
# 2                    ['Action', 'Adventure', 'Crime']
# 3            ['Action', 'Crime', 'Drama', 'Thriller']
# 4          ['Action', 'Adventure', 'Science Fiction']
# 5                  ['Fantasy', 'Action', 'Adventure']
# 6                             ['Animation', 'Family']
# 7          ['Action', 'Adventure', 'Science Fiction']
# 8                  ['Adventure', 'Fantasy', 'Family']
# 9                  ['Action', 'Adventure', 'Fantasy']
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...
# 11       ['Adventure', 'Action', 'Thriller', 'Crime']
# 12                 ['Adventure', 'Fantasy', 'Action']
# 13                 ['Action', 'Adventure', 'Western']
# 14  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 15                 ['Adventure', 'Family', 'Fantasy']
# ...

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task-2: Identify the columns that have null values and perform the null value treatment. (Choose the imputation method based on the type of data in the columns of interest)

# %%
#CHECKING FOR NULL VALUES::
DATA.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# Task-3: Display the movie categories that have a budget greater than $220,000.

# %%
BUDGET=DATA[DATA["budget"]>220000]
BUDGET
# Out:
#          budget                                             genres  \
# 0     237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1     300000000                 ['Adventure', 'Fantasy', 'Action']
# 2     245000000                   ['Action', 'Adventure', 'Crime']
# 3     250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 4     260000000         ['Action', 'Adventure', 'Science Fiction']
# ...         ...                                                ...
# 4680     450000                    ['Crime', 'Horror', 'Thriller']
# 4682   13000000                                         ['Horror']
# 4720    8500000                                          ['Drama']
# 4758    4000000                    ['Thriller', 'Science Fiction']
# 4770     500000                                ['Drama', 'Comedy']
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %%
BUDGET[["budget","genres","original_title","title"]]
# Out:
#          budget                                             genres  \
# 0     237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1     300000000                 ['Adventure', 'Fantasy', 'Action']
# 2     245000000                   ['Action', 'Adventure', 'Crime']
# 3     250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 4     260000000         ['Action', 'Adventure', 'Science Fiction']
# ...         ...                                                ...
# 4680     450000                    ['Crime', 'Horror', 'Thriller']
# 4682   13000000                                         ['Horror']
# 4720    8500000                                          ['Drama']
# 4758    4000000                    ['Thriller', 'Science Fiction']
# 4770     500000                                ['Drama', 'Comedy']
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# ...

# %%
BUDGET.shape[0]
# Out:
# 3684

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# Task-4: Display the movie categories where the revenue is greater than $961,000,000.

# %%
REVENUE=DATA[DATA["revenue"]>961000000]
REVENUE
# Out:
#         budget                                             genres  \
# 0    237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 3    250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 7    280000000         ['Action', 'Adventure', 'Science Fiction']
# 12   200000000                 ['Adventure', 'Fantasy', 'Action']
# 16   220000000         ['Science Fiction', 'Action', 'Adventure']
# 17   380000000                 ['Adventure', 'Action', 'Fantasy']
# 25   200000000                   ['Drama', 'Romance', 'Thriller']
# 26   250000000         ['Adventure', 'Action', 'Science Fiction']
# 28   150000000  ['Action', 'Adventure', 'Science Fiction', 'Th...
# 29   200000000                ['Action', 'Adventure', 'Thriller']
# 31   200000000         ['Action', 'Adventure', 'Science Fiction']
# 32   200000000                 ['Family', 'Fantasy', 'Adventure']
# 36   210000000         ['Science Fiction', 'Action', 'Adventure']
# ...

# %%
REVENUE[["genres","original_title","revenue","title"]]
# Out:
#                                                 genres  \
# 0    ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 3             ['Action', 'Crime', 'Drama', 'Thriller']
# 7           ['Action', 'Adventure', 'Science Fiction']
# 12                  ['Adventure', 'Fantasy', 'Action']
# 16          ['Science Fiction', 'Action', 'Adventure']
# 17                  ['Adventure', 'Action', 'Fantasy']
# 25                    ['Drama', 'Romance', 'Thriller']
# 26          ['Adventure', 'Action', 'Science Fiction']
# 28   ['Action', 'Adventure', 'Science Fiction', 'Th...
# 29                 ['Action', 'Adventure', 'Thriller']
# 31          ['Action', 'Adventure', 'Science Fiction']
# 32                  ['Family', 'Fantasy', 'Adventure']
# 36          ['Science Fiction', 'Action', 'Adventure']
# 42                   ['Animation', 'Family', 'Comedy']
# 44                                          ['Action']
# 52          ['Action', 'Science Fiction', 'Adventure']
# ...

# %%
REVENUE.shape[0]
# Out:
# 24

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# Task-5: In the dataset, there are some movies for which the budget and revenue columns have the value 0, which mean unknown values. Remove the rows with value 0 from both the budget and revenue columns.

# %%
#CLEAN DATA::
X=DATA[(DATA["revenue"]!=0) & (DATA["budget"]!=0)]
X.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 4  260000000         ['Action', 'Adventure', 'Science Fiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [raw]
# Task-6: List the top 10 movies with the highest revenues and the top 10 movies with the least budget.

# %%
T=X.sort_values(by="revenue",ascending=False)

# %%
#TOP 10 MOVIES WITH HIGHEST REVENUE::
T10=T[['title', 'runtime', "budget", "revenue","popularity","vote_count"]].head(10)
T10
# Out:
#                           title  runtime     budget     revenue  popularity  \
# 0                        Avatar    162.0  237000000  2787965087  150.437577
# 25                      Titanic    194.0  200000000  1845034188  100.025899
# 16                 The Avengers    143.0  220000000  1519557910  144.448633
# 28               Jurassic World    124.0  150000000  1513528810  418.708552
# 44                    Furious 7    137.0  190000000  1506249360  102.322217
# 7       Avengers: Age of Ultron    141.0  280000000  1405403694  134.279229
# 124                      Frozen    102.0  150000000  1274219009  165.125366
# 31                   Iron Man 3    130.0  200000000  1215439994   77.682080
# 546                     Minions     91.0   74000000  1156730962  875.581305
# 26   Captain America: Civil War    147.0  250000000  1153304495  198.372395
#
#      vote_count
# 0         11800
# 25         7562
# 16        11776
# 28         8662
# 44         4176
# 7          6767
# ...

# %%
#BAR GRAPH
PLT.figure(figsize=(12, 7))
SNS.barplot(x='revenue', y='title', data=T10)
PLT.xlabel('REVENUE IN MILLIONS')
PLT.ylabel('MOVIES')
PLT.title('TOP 10 MOVIES BASED ON REVENUE')
PLT.show()

# %%
L=X.sort_values(by="budget",ascending=True)

# %%
#TOP 10 MOVIES WITH LEAST REVENUE::
L10=L[['title', 'runtime',"budget","popularity","vote_count"]].head(10)
L10
# Out:
#                    title  runtime  budget  popularity  vote_count
# 4238        Modern Times     87.0       1   28.276480         856
# 3611  A Farewell to Arms     89.0       4    1.199451          28
# 3372        Split Second     90.0       7    4.857028          63
# 3419        Bran Nue Dae     82.0       7    0.050456           6
# 4608        The Prophecy     98.0       8   11.818333         138
# 3131   Of Horses and Men     85.0      10    1.617943          26
# 3137           Nurse 3-D     99.0      10   10.013629         119
# 2933            F.I.S.T.    145.0      11    3.375208          29
# 1912      Angela's Ashes    145.0      25    4.887940          59
# 1771      The 51st State     93.0      28    9.670031         173

# %%
#BAR GRAPH
PLT.figure(figsize=(12, 7))
SNS.barplot(x='budget', y='title', data=L10)
PLT.xlabel('BUDGET IN MILLIONS')
PLT.ylabel('MOVIES')
PLT.title('TOP 10 LEAST-MOVIES BASED ON BUDGET')
PLT.show()

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task-7: How are popularities of movies related with the movie budgets? Are they correlated or totally uncorrelated with each other? Write the interpretation of your analysis.

# %%
x=X["popularity"]
y=X["budget"]
PLT.scatter(x,y,color="blue");
PLT.title("BUDGET  VS POPULARITY")
PLT.ylabel('BUDGET')
PLT.xlabel('POPULARITY')
z=NP.polyfit(x,y,1)
p=NP.poly1d(z)
PLT.plot(x,p(x),"red");

# %%
corrs=X["budget"].corr(X["popularity"])
y=X["budget"]
x=X["popularity"]
PLT.scatter(x,y,color="blue");
PLT.title("BUDGET  VS POPULARITY")
PLT.ylabel('POPULARITY')
PLT.xlabel('BUDGET')
PLT.show()
print("CORRELATION OF BUDGET AND POPULARITY=",corrs)

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task - 8: Identify and display the names of all production companies along with the number of times they appear in the dataset.

# %%
import json
# Convert the string representation of production companies into a list of dictionaries
DATA['production_companies'] = DATA['production_companies'].apply(lambda x: json.loads(x))

# %%
# # Initialize an empty dictionary to store production company names and their counts
production_counts = {}

# Iterate over each row in the DataFrame
for row in DATA.itertuples(index=False):
    # Iterate over each production company in the row
    for company in row.production_companies:
        # Extract the production company name
        company_name = company['name']
        
        # Increment the count for the production company
        if company_name in production_counts:
            production_counts[company_name] += 1
        else:
            production_counts[company_name] = 1

# Create a new DataFrame to store the production company names and their counts
production_df = PD.DataFrame({'Production Company': list(production_counts.keys()), 'Count': list(production_counts.values())})

# Sort the DataFrame by count in descending order
production_df = production_df.sort_values('Count', ascending=False)
production_df
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# ...                                      ...    ...
# 2323                         Greenlit Rights      1
# 2324                           Q Productions      1
# 2325                           Central Films      1
# 2326                   Goodspeed Productions      1
# 5016                        lucky crow films      1
#
# [5017 rows x 2 columns]

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task-9: Display the names of the top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced.

# %%
# Sort the DataFrame by count in descending order
production_df = production_df.sort_values('Count', ascending=False)

# Select the top 25 production companies based on count
top_25_companies_pc = production_df.head(25)
top_25_companies_pc
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# 46                           New Line Cinema    165
# 49                 Metro-Goldwyn-Mayer (MGM)    122
# 200                      Touchstone Pictures    118
# 4                       Walt Disney Pictures    114
# 54                          Relativity Media    102
# 257            Columbia Pictures Corporation     96
# 391                            Miramax Films     94
# 112                Village Roadshow Pictures     81
# 80                            DreamWorks SKG     79
# 532                           United Artists     75
# 370                                   Canal+     75
# 296                      Regency Enterprises     69
# ...

# %%
top_10_pc=top_25_companies_pc.nlargest(25, "Count").sort_values(by="Count", ascending =False)
PLT.figure(figsize=(12, 7))
SNS.barplot(y='Production Company', x='Count', data=top_10_pc)
PLT.xlabel('COUNT OF PRODUCTION COMPANIES')
PLT.ylabel('PRODUCTION COMPANIES')
PLT.title('Top 10 production companies by movie count')
PLT.show()

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task 10: Sort the data in descending order based on revenue and filter the top 500 movies. Find the measures of central tendency for the following columns using the filtered data:
# 1. budget
# 2. revenue
# 3. runtime
#
# Perform outlier analysis for the above three columns using box plots.

# %%
#TOP 500 ROWS BASE ON REVENUE::
Sort=X.sort_values(by="revenue",ascending=False)[:500]

# %%
#CENTRAL TENDANCY::
def info_of_numerical(col):
    print(f"The mean of the {col} is:: {Sort[col].mean()}")
    print(f"The median of the {col} is:: {Sort[col].median()}")
    print(f"The mode of the {col} is :: {Sort[col].mode()[0]}")
    print(f"The standard deviation of the {col} is :: {Sort[col].std()}")
    print(f"Number of missing values in the {col} is :: {Sort[col].isnull().sum()}")

# %%
#BUDGET COLUMN::
info_of_numerical("budget")

# %%
#REVENUE COLUMN::
info_of_numerical("revenue")

# %%
#RUNTIME COLUMN::
info_of_numerical("runtime")

# %%
#BOX PLOT
fig,ax=PLT.subplots(1,3,figsize=(15,5))
SNS.boxplot(y=Sort['budget'],ax=ax[0], color="orange")
SNS.boxplot(y=Sort['revenue'],ax=ax[2],color="teal")
SNS.boxplot(y=Sort['runtime'],ax=ax[1],color="green")
PLT.show()

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# Task 11: Identify and display the names of the movies along with their run times for those movies that have above average runtime, using the data from the previous task.

# %%
A=X.runtime.mean()
A
# Out:
# 110.72437287085785

# %%
B=X[X["runtime"]>=A]

# %%
B[["genres","original_title","runtime"]]
# Out:
#                                                  genres  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1                    ['Adventure', 'Fantasy', 'Action']
# 2                      ['Action', 'Adventure', 'Crime']
# 3              ['Action', 'Crime', 'Drama', 'Thriller']
# 4            ['Action', 'Adventure', 'Science Fiction']
# ...                                                 ...
# 4631                     ['Comedy', 'Drama', 'Romance']
# 4661                        ['Drama', 'Romance', 'War']
# 4720                                          ['Drama']
# 4722                                          ['Drama']
# 4792         ['Crime', 'Horror', 'Mystery', 'Thriller']
#
#                                 original_title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# ...

# %%
fig, ax=PLT.subplots(figsize=(20,7))
SNS.heatmap(DATA.corr(), annot=True, cbar=0.5, linewidth=0.5, cmap="coolwarm")
PLT.show()

# %% [raw]
# The correlation between movie popularity and budget is 0.4604. This indicates a moderate positive correlation. In simpler terms, movies with higher budgets tend to have higher levels of popularity. However, it's important to note that correlation does not imply causation. Other factors also play a role in a movie's popularity, such as its quality, marketing efforts, and cast. Therefore, while budget and popularity are positively related, there are additional factors to consider in determining a movie's success.

# %% [raw]
# ================================================================================================================================================================================================================================================================
